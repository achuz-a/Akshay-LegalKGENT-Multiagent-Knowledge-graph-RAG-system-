# %%
import requests
import json

response = requests.post(
    url="https://lightning.ai/api/v1/chat/completions",
    headers={
        "Authorization": "Bearer 8645f613-f44c-4ec9-a895-f1aa69bf76dc/sr1777/deploy-model-project",
        "Content-Type": "application/json",
    },
    data=json.dumps({
        "model": "lightning-ai/DeepSeek-V3.1",
        "messages": [
          {
            "role": "user",
            "content": [{ "type": "text", "text": "genrate a story of 3000 words " }]
          },
        ],
        
    })
)
print(json.loads(response.content)['choices'][0]['message']['content'])
# Out:
# The dust in the air was not merely particulate; it was memory. Each mote that danced in the slanted afternoon light was a fragment of eroded stone, a ghost of a painted mural, a dissolved prayer. Elara breathed it in, and it tasted of forgotten kings and silent bells. Her fingers, caked in the fine, ochre powder of the place, traced the edge of a bas-relief, following the sinuous curve of a serpent-god’s tail. The desert outside the ruins of Khal-Zar baked under a merciless sun, but here, in the deep, labyrinthine corridors of the temple complex, a profound and ancient coolness persisted.
#
# ...

# %%
GROQ_API_KEY="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"
from groq import Groq
       

client = Groq(    api_key=GROQ_API_KEY,
)
completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
      {
        "role": "user",
        "content": "hii"
      }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# Hi, how can I assist you today?

# %%
from groq import Groq
